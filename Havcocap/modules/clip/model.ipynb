# %% [markdown]
# # ALL TRANFORMER BLOCK EXPLAINED IN DETAIL

# %% [markdown]
# ## 1. RESIDUAL_ATTENTION_BLOCK
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. VISION_TRANSFORMER
# ![image.png](attachment:image.png)
